# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'd701bd41-676b-4cbd-9cb1-f6c446d80326',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2024-01-03T18:25:29.791Z', 'error_code': 0, 'error_message': None, 'elapsed': 25, 'credit_count': 1, 'notice': None, 'total_count': 8986}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10691, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'pa
# ...

# %%
type(data)
# Out:
# dict

# %%
#use pandas to change jsontype(dict) to a table in order to understande it easly

import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)


df=pd.json_normalize(data['data'])
df['current_time']=pd.Timestamp.now()
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10691
# 1    1027     Ethereum    ETH      ethereum              8172
# 2     825  Tether USDt   USDT        tether             70426
# 3    1839          BNB    BNB           bnb              1970
# 4    5426       Solana    SOL        solana               610
# 5      52          XRP    XRP           xrp              1195
# 6    3408         USDC   USDC      usd-coin             15951
# 7    2010      Cardano    ADA       cardano              1018
# 8    5805    Avalanche   AVAX     avalanche               628
# 9      74     Dogecoin   DOGE      dogecoin               865
# 10   6636     Polkadot    DOT  polkadot-new               658
# 11   1958         TRON    TRX          tron               894
# 12   3890      Polygon  MATIC       polygon              1220
# 13   1975    Chainlink   LINK     chainlink              1547
# ...

# %%
def api_runner():
    
    global df
    import pandas as pd
    from requests import Request, Session
    from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
    import json

    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
     'start':'1',
     'limit':'15',
     'convert':'USD'
    }
    headers = {
     'Accepts': 'application/json',
     'X-CMC_PRO_API_KEY': 'd701bd41-676b-4cbd-9cb1-f6c446d80326',
    }

    session = Session()
    session.headers.update(headers)

    try:
     response = session.get(url, params=parameters)
     data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
     print(e)
    
    df=pd.json_normalize(data['data'])
    df['current_time']=pd.Timestamp.now()
    df 
    if not os.path.isfile(r'C:\Users\hp\Downloads\Amazon_scrap\API.csv'):
        df.to_csv(r'C:\Users\hp\Downloads\Amazon_scrap\API.csv', header = 'column_names')
    else:
        df.to_csv(r'C:\Users\hp\Downloads\Amazon_scrap\API.csv',mode='a',header = False)

# %%
import os
from time import time
from time import sleep

for i  in range(300):
    api_runner()
    print('API complited Successfully')
    sleep(60) #sleep for a minute and run again
exit()
# Out:
# API complited Successfully
# API complited Successfully
# API complited Successfully

# %%
import pandas as pd
df3=pd.read_csv(r'C:\Users\hp\Downloads\Amazon_scrap\API.csv')
df3

# %%
pd.set_option('display.float_format', lambda x: '%.5f' %x )

# %%
df

# %%
# Now let's look at the coin trends over time

df4 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3828\4274599756.py in <module>
#       1 # Now let's look at the coin trends over time
#       2
# ----> 3 df4 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
#       4 df4
#
# NameError: name 'df' is not defined

# %%
df5=df4.stack()
df5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3828\2196779529.py in <module>
# ----> 1 df5=df4.stack()
#       2 df5
#
# NameError: name 'df4' is not defined

# %%
type(df5)

# %%
df6 = df5.to_frame(name='values')
df6

# %%
df6.count()

# %%
#Because of how it's structured above we need to set an index. I don't want to pass a column as an index for this dataframe
#So I'm going to create a range and pass that as the dataframe. You can make this more dynamic, but I'm just going to hard code it


index = pd.Index(range(90))

# Set the above DataFrame index object as the index
# using set_index() function
df7 = df6.set_index(index)
df7

# If it only has the index and values try doing reset_index like "df5.reset_index()"

# %%
# Change the column name

df8 = df7.rename(columns={'level_1': 'percent_change'})
df8

# %%
df8['percent_change'] = df8['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['24h','7d','30d','60d','90d'])
df8

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df8, kind='point')

# %%
# Now to do something much simpler
# we are going to create a dataframe with the columns we want

df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
